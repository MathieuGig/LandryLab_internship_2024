# %% [markdown]
# # Make Synthetic Genome
# Author : Mathieu Giguere \
# Date : 02/07/2024 \
# Brief : Strings together the genes of interest of some species into a singular synthetic genome. \
# Dependencies :

# %% [markdown]
# ## Plan
#
# ### 1. Read genome files (fasta) -> big string
# ### 2. Read gffs files -> then use regex to extract the coordinates of the genes of interest
# ### 3. For each genome, for each gene of interest, extract its dna sequence in the appropriate genome file
# ### 4. Append each string into 1 genome with spacers
# ### 5. Write synthetic genome file in fasta format

# %%
import re
import pandas as pd

# %%
species_genome_file_list = ["fasta_files/unzipped/Aspergillus_fumigatus.ASM265v1.dna.toplevel.fa",
                           "fasta_files/unzipped/C_albicans_SC5314_version_A22-s07-m01-r195_chromosomes.fasta",
                           "fasta_files/unzipped/C_auris_B8441_version_s01-m03-r08_chromosomes.fasta",
                           "fasta_files/unzipped/C_glabrata_CBS138_version_s05-m03-r06_chromosomes.fasta",
                           "fasta_files/unzipped/C_parapsilosis_CDC317_version_s01-m06-r03_chromosomes.fasta",
                           "fasta_files/unzipped/Candida_tropicalis.GCA000006335v3.dna.toplevel.fa",
                           "fasta_files/unzipped/Cryptococcus_neoformans.ASM9104v1.dna.toplevel.fa",
                           "fasta_files/unzipped/Pichia_kudriavzevii_gca_000764455.ASM76445v1.dna.toplevel.fa"]

species_list = ["Aspergillus fumigatus", "Candida albicans", "Candida auris", "Nasakeomyces glabrata", "Candida parapsilosis", "Candida tropicalis", "Cryptococcus neoformans", "Pichia kudriavzevii"]

gff_files_list = ["gff_files/Aspergillus_fumigatus.ASM265v1.59.gff3",
                 "gff_files/C_albicans_SC5314_version_A22-s07-m01-r195.gff",
                 "gff_files/C_auris_B8441_version_s01-m03-r08.gff",
                 "gff_files/C_glabrata_CBS138_version_s05-m03-r06.gff",
                 "gff_files/C_parapsilosis_CDC317_version_s01-m06-r03.gff",
                 "gff_files/Candida_tropicalis.GCA000006335v3.59.gff3",
                 "gff_files/Cryptococcus_neoformans.ASM9104v1.59.gff3",
                 "gff_files/Pichia_kudriavzevii_gca_000764455.ASM76445v1.59.gff3"]

# %%
# Make dataframe that links the species to their genes of interest

df = pd.read_csv("gene-species.csv")

df = df.groupby('Species')['Gene ID'].apply(list).reset_index()

df
# Out:
#                    Species                                            Gene ID
# 0    Aspergillus fumigatus  [AFUA_4G06890, AFUA_6G05140, AFUA_2G00320, AFU...
# 1         Candida albicans  [C5_00660C_A, C1_04770C_A, C1_02420C_A, CR_008...
# 2            Candida auris  [B9J08_001448, B9J08_003737, B9J08_000964, B9J...
# 3     Candida parapsilosis  [CPAR2_303740, CPAR2_105550, CPAR2_106400, CPA...
# 4       Candida tropicalis  [CTRG_05283, CTRG_04480, CTRG_04661, CTRG_0268...
# 5  Cryptococcus neoformans  [CNA00300, CNN02320, CNE02100, CNA05950, CNF04...
# 6    Nasakeomyces glabrata  [CAGL0E04334g, CAGL0F01793g, CAGL0G01034g, CAG...
# 7      Pichia kudriavzevii  [JL09_g2508, JL09_g3074, JL09_g1956, JL09_g200...

# %%
synth = ""
spacer = "NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN"

for i, file in enumerate(species_genome_file_list):
    species = species_list[i]
    print(species)
    with open(file) as genome:
        genome_content = genome.read()
    
    # Removes first line puts a space
    dna = re.sub(">.*", "", genome_content)
    dna = re.sub("\n", "", dna)
    
    gff_file = gff_files_list[i]
    with open(gff_file) as gff:
        gff_content = gff.read()
    
    gene_list = df['Gene ID'][df['Species'] == species].values[0]
    
    for g in gene_list:
        print(f'Gene ID : {g}')
        
        # find gene coordinates
        #y = re.findall(f"^.*\\tgene\\t.*?{g};", gff_content)
        y = re.findall(f"^.*\\t.*\\tgene\\t.*?{g}", gff_content, flags=re.MULTILINE)
        print(y)
        #coordinates = re.sub("\t", "", y[0])
        coordinates = re.findall("[0-9+-]+", y[0])
        print(f'Coordinates : {coordinates[0:4]}')
        #begin = int(coordinates[0])
        #end = int(coordinates[1])
        #strand = coordinates[2]
        
        #gene_seq = dna[begin-1:end]
        
        #print(f'Gene length : {len(gene_seq)}')
        #print(gene_seq)
        #synth += gene_seq + spacer * 5
    
    #synth += spacer * 5
# Out:
# Aspergillus fumigatus
# Gene ID : AFUA_4G06890
# ['4\tena\tgene\t1780204\t1781822\t.\t-\t.\tID=gene:AFUA_4G06890']
# Coordinates : ['4', '1780204', '1781822', '-']
# Gene ID : AFUA_6G05140
# ['6\tena\tgene\t1228802\t1229934\t.\t-\t.\tID=gene:AFUA_6G05140']
# Coordinates : ['6', '1228802', '1229934', '-']
# Gene ID : AFUA_2G00320
# ['2\tena\tgene\t61020\t62153\t.\t+\t.\tID=gene:AFUA_2G00320']
# Coordinates : ['2', '61020', '62153', '+']
# Gene ID : AFUA_6G12400
# ['6\tena\tgene\t3126474\t3132292\t.\t-\t.\tID=gene:AFUA_6G12400']
# Coordinates : ['6', '3126474', '3132292', '-']
# Gene ID : AFUA_5G05460
# ['5\tena\tgene\t1268053\t1268981\t.\t-\t.\tID=gene:AFUA_5G05460']
# Coordinates : ['5', '1268053', '1268981', '-']
# Gene ID : AFUA_1G05050
# ['1\tena\tgene\t1449702\t1450353\t.\t+\t.\tID=gene:AFUA_1G05050']
# Coordinates : ['1', '1449702', '1450353', '+']
# Gene ID : AFUA_2G15130
# ['2\tena\tgene\t3997636\t4002389\t.\t-\t.\tID=gene:AFUA_2G15130']
# Coordinates : ['2', '3997636', '4002389', '-']
# Gene ID : AFUA_4G12560
# ['4\tena\tgene\t3289801\t3292477\t.\t-\t.\tID=gene:AFUA_4G12560']
# Coordinates : ['4', '3289801', '3292477', '-']
# Gene ID : AFUA_2G03700
# ['2\tena\tgene\t984934\t988503\t.\t+\t.\tID=gene:AFUA_2G03700']
# Coordinates : ['2', '984934', '988503', '+']
# Gene ID : AFUA_3G05760
# ['3\tena\tgene\t1406209\t1407279\t.\t-\t.\tID=gene:AFUA_3G05760']
# Coordinates : ['3', '1406209', '1407279', '-']
# Gene ID : AFUA_5G06070
# ['5\tena\tgene\t1446973\t1451166\t.\t+\t.\tID=gene:AFUA_5G06070']
# Coordinates : ['5', '1446973', '1451166', '+']
# Gene ID : AFUA_1G10910
# ['1\tena\tgene\t2848155\t2850137\t.\t-\t.\tID=gene:AFUA_1G10910']
# Coordinates : ['1', '2848155', '2850137', '-']
# Gene ID : AFUA_5G10370
# ['5\tena\tgene\t2654821\t2655836\t.\t-\t.\tID=gene:AFUA_5G10370']
# Coordinates : ['5', '2654821', '2655836', '-']
# Gene ID : AFUA_7G03740
# ['7\tena\tgene\t804301\t806031\t.\t-\t.\tID=gene:AFUA_7G03740']
# Coordinates : ['7', '804301', '806031', '-']
# Candida albicans
# Gene ID : C5_00660C_A
# ['Ca22chr5A_C_albicans_SC5314\tCGD\tgene\t148115\t149701\t.\t-\t.\tID=C5_00660C_A']
# Coordinates : ['22', '5', '5314', '148115']
# Gene ID : C1_04770C_A
# ['Ca22chr1A_C_albicans_SC5314\tCGD\tgene\t991622\t992782\t.\t-\t.\tID=C1_04770C_A']
# Coordinates : ['22', '1', '5314', '991622']
# Gene ID : C1_02420C_A
# ['Ca22chr1A_C_albicans_SC5314\tCGD\tgene\t505969\t511662\t.\t-\t.\tID=C1_02420C_A']
# Coordinates : ['22', '1', '5314', '505969']
# Gene ID : CR_00850C_A
# ['Ca22chrRA_C_albicans_SC5314\tCGD\tgene\t192172\t197094\t.\t-\t.\tID=CR_00850C_A']
# Coordinates : ['22', '5314', '192172', '197094']
# Gene ID : C5_03390C_A
# ['Ca22chr5A_C_albicans_SC5314\tCGD\tgene\t766244\t766900\t.\t-\t.\tID=C5_03390C_A']
# Coordinates : ['22', '5', '5314', '766244']
# Gene ID : C6_00620W_A
# ['Ca22chr6A_C_albicans_SC5314\tCGD\tgene\t112252\t112774\t.\t+\t.\tID=C6_00620W_A']
# Coordinates : ['22', '6', '5314', '112252']
# Gene ID : C3_05920W_A
# ['Ca22chr3A_C_albicans_SC5314\tCGD\tgene\t1329263\t1332589\t.\t+\t.\tID=C3_05920W_A']
# Coordinates : ['22', '3', '5314', '1329263']
# Gene ID : C3_05220W_A
# ['Ca22chr3A_C_albicans_SC5314\tCGD\tgene\t1146045\t1150550\t.\t+\t.\tID=C3_05220W_A']
# Coordinates : ['22', '3', '5314', '1146045']
# Gene ID : C5_01840C_A
# ['Ca22chr5A_C_albicans_SC5314\tCGD\tgene\t416400\t419345\t.\t-\t.\tID=C5_01840C_A']
# Coordinates : ['22', '5', '5314', '416400']
# Gene ID : C1_08460C_A
# ['Ca22chr1A_C_albicans_SC5314\tCGD\tgene\t1858136\t1860274\t.\t-\t.\tID=C1_08460C_A']
# Coordinates : ['22', '1', '5314', '1858136']
# Gene ID : C3_04890W_A
# ['Ca22chr3A_C_albicans_SC5314\tCGD\tgene\t1047887\t1052386\t.\t+\t.\tID=C3_04890W_A']
# Coordinates : ['22', '3', '5314', '1047887']
# Gene ID : C3_07860C_A
# ['Ca22chr3A_C_albicans_SC5314\tCGD\tgene\t1778415\t1780547\t.\t-\t.\tID=C3_07860C_A']
# Coordinates : ['22', '3', '5314', '1778415']
# Gene ID : C6_03170C_A
# ['Ca22chr6A_C_albicans_SC5314\tCGD\tgene\t666383\t668077\t.\t-\t.\tID=C6_03170C_A']
# Coordinates : ['22', '6', '5314', '666383']
# Gene ID : C1_08590C_A
# ['Ca22chr1A_C_albicans_SC5314\tCGD\tgene\t1880547\t1882037\t.\t-\t.\tID=C1_08590C_A']
# Coordinates : ['22', '1', '5314', '1880547']
# Gene ID : C3_02220W_A
# ['Ca22chr3A_C_albicans_SC5314\tCGD\tgene\t478901\t480400\t.\t+\t.\tID=C3_02220W_A']
# Coordinates : ['22', '3', '5314', '478901']
# Gene ID : C1_00800C_A
# ['Ca22chr1A_C_albicans_SC5314\tCGD\tgene\t154633\t155286\t.\t-\t.\tID=C1_00800C_A']
# Coordinates : ['22', '1', '5314', '154633']
# Gene ID : C1_03780C_A
# ['Ca22chr1A_C_albicans_SC5314\tCGD\tgene\t790364\t793585\t.\t-\t.\tID=C1_03780C_A']
# Coordinates : ['22', '1', '5314', '790364']
# Gene ID : C3_06850W_A
# ['Ca22chr3A_C_albicans_SC5314\tCGD\tgene\t1568451\t1570004\t.\t+\t.\tID=C3_06850W_A']
# Coordinates : ['22', '3', '5314', '1568451']
# Gene ID : CR_08780W_A
# ['Ca22chrRA_C_albicans_SC5314\tCGD\tgene\t1893023\t1893161\t.\t+\t.\tID=CR_08780W_A']
# Coordinates : ['22', '5314', '1893023', '1893161']
# Gene ID : CR_08800W_A
# ['Ca22chrRA_C_albicans_SC5314\tCGD\tgene\t1893319\t1893469\t.\t+\t.\tID=CR_08800W_A']
# Coordinates : ['22', '5314', '1893319', '1893469']
# Gene ID : C1_00710C_A
# ['Ca22chr1A_C_albicans_SC5314\tCGD\tgene\t123869\t125597\t.\t-\t.\tID=C1_00710C_A']
# Coordinates : ['22', '1', '5314', '123869']
# Candida auris
# Gene ID : B9J08_001448
# ['PEKT02000003_C_auris_B8441\tCGD\tgene\t832733\t834307\t.\t-\t.\tID=B9J08_001448']
# Coordinates : ['02000003', '8441', '832733', '834307']
# Gene ID : B9J08_003737
# ['PEKT02000007_C_auris_B8441\tCGD\tgene\t2369962\t2371053\t.\t-\t.\tID=B9J08_003737']
# Coordinates : ['02000007', '8441', '2369962', '2371053']
# Gene ID : B9J08_000964
# ['PEKT02000002_C_auris_B8441\tCGD\tgene\t1002873\t1008539\t.\t-\t.\tID=B9J08_000964']
# Coordinates : ['02000002', '8441', '1002873', '1008539']
# Gene ID : B9J08_001020
# ['PEKT02000002_C_auris_B8441\tCGD\tgene\t1145621\t1151000\t.\t+\t.\tID=B9J08_001020']
# Coordinates : ['02000002', '8441', '1145621', '1151000']
# Gene ID : B9J08_004076
# ['PEKT02000007_C_auris_B8441\tCGD\tgene\t3118161\t3118817\t.\t-\t.\tID=B9J08_004076']
# Coordinates : ['02000007', '8441', '3118161', '3118817']
# Gene ID : B9J08_005397
# ['PEKT02000010_C_auris_B8441\tCGD\tgene\t1098264\t1098764\t.\t+\t.\tID=B9J08_005397']
# Coordinates : ['02000010', '8441', '1098264', '1098764']
# Gene ID : B9J08_000164
# ['PEKT02000001_C_auris_B8441\tCGD\tgene\t348521\t353047\t.\t-\t.\tID=B9J08_000164']
# Coordinates : ['02000001', '8441', '348521', '353047']
# Gene ID : B9J08_004061
# ['PEKT02000007_C_auris_B8441\tCGD\tgene\t3093802\t3096522\t.\t+\t.\tID=B9J08_004061']
# Coordinates : ['02000007', '8441', '3093802', '3096522']
# Gene ID : B9J08_004819
# ['PEKT02000009_C_auris_B8441\tCGD\tgene\t811685\t814102\t.\t+\t.\tID=B9J08_004819']
# Coordinates : ['02000009', '8441', '811685', '814102']
# Gene ID : B9J08_000270
# ['PEKT02000001_C_auris_B8441\tCGD\tgene\t559186\t561039\t.\t-\t.\tID=B9J08_000270']
# Coordinates : ['02000001', '8441', '559186', '561039']
# Gene ID : B9J08_003224
# ['PEKT02000007_C_auris_B8441\tCGD\tgene\t1275799\t1278858\t.\t+\t.\tID=B9J08_003224']
# Coordinates : ['02000007', '8441', '1275799', '1278858']
# Gene ID : B9J08_001232
# ['PEKT02000003_C_auris_B8441\tCGD\tgene\t355067\t356446\t.\t-\t.\tID=B9J08_001232']
# Coordinates : ['02000003', '8441', '355067', '356446']
# Gene ID : B9J08_001055.75
# ['PEKT02000002_C_auris_B8441\tCGD\tgene\t1233164\t1233237\t.\t-\t.\tID=B9J08_001055.75']
# Coordinates : ['02000002', '8441', '1233164', '1233237']
# Gene ID : B9J08_001055.25
# ['PEKT02000002_C_auris_B8441\tCGD\tgene\t1232915\t1232998\t.\t-\t.\tID=B9J08_001055.25']
# Coordinates : ['02000002', '8441', '1232915', '1232998']
# Gene ID : B9J08_003245
# ['PEKT02000007_C_auris_B8441\tCGD\tgene\t1331362\t1332774\t.\t+\t.\tID=B9J08_003245']
# Coordinates : ['02000007', '8441', '1331362', '1332774']
# Nasakeomyces glabrata
# Gene ID : CAGL0E04334g
# ['ChrE_C_glabrata_CBS138\tCGD\tgene\t431513\t434697\t.\t-\t.\tID=CAGL0E04334g']
# Coordinates : ['138', '431513', '434697', '-']
# Gene ID : CAGL0F01793g
# ['ChrF_C_glabrata_CBS138\tCGD\tgene\t200332\t201893\t.\t-\t.\tID=CAGL0F01793g']
# Coordinates : ['138', '200332', '201893', '-']
# Gene ID : CAGL0G01034g
# ['ChrG_C_glabrata_CBS138\tCGD\tgene\t106787\t112983\t.\t+\t.\tID=CAGL0G01034g']
# Coordinates : ['138', '106787', '112983', '+']
# Gene ID : CAGL0K04037g
# ['ChrK_C_glabrata_CBS138\tCGD\tgene\t374455\t381959\t.\t+\t.\tID=CAGL0K04037g']
# Coordinates : ['138', '374455', '381959', '+']
# Gene ID : CAGL0H09064g
# ['ChrH_C_glabrata_CBS138\tCGD\tgene\t889838\t891329\t.\t-\t.\tID=CAGL0H09064g']
# Coordinates : ['138', '889838', '891329', '-']
# Gene ID : CAGL0D01562g
# ['ChrD_C_glabrata_CBS138\tCGD\tgene\t175952\t178597\t.\t-\t.\tID=CAGL0D01562g']
# Coordinates : ['138', '175952', '178597', '-']
# Gene ID : CAGL0A00451g
# ['ChrA_C_glabrata_CBS138\tCGD\tgene\t58951\t65834\t.\t+\t.\tID=CAGL0A00451g']
# Coordinates : ['138', '58951', '65834', '+']
# Gene ID : CAGL0I07733g
# ['ChrI_C_glabrata_CBS138\tCGD\tgene\t744457\t747469\t.\t+\t.\tID=CAGL0I07733g']
# Coordinates : ['138', '744457', '747469', '+']
# Gene ID : CAGL0M01760g
# ['ChrM_C_glabrata_CBS138\tCGD\tgene\t212900\t218303\t.\t+\t.\tID=CAGL0M01760g']
# Coordinates : ['138', '212900', '218303', '+']
# Gene ID : CAGL0I07755g
# ['ChrI_C_glabrata_CBS138\tCGD\tgene\t747488\t750797\t.\t-\t.\tID=CAGL0I07755g']
# Coordinates : ['138', '747488', '750797', '-']
# Gene ID : CAGL0F07865g
# ['ChrF_C_glabrata_CBS138\tCGD\tgene\t791275\t795146\t.\t-\t.\tID=CAGL0F07865g']
# Coordinates : ['138', '791275', '795146', '-']
# Gene ID : CAGL0L11506g
# ['ChrL_C_glabrata_CBS138\tCGD\tgene\t1239146\t1243034\t.\t+\t.\tID=CAGL0L11506g']
# Coordinates : ['138', '1239146', '1243034', '+']
# Gene ID : CAGL0L13392r
# ['ChrL_C_glabrata_CBS138\tCGD\tgene\t1479245\t1479645\t.\t-\t.\tID=CAGL0L13392r']
# Coordinates : ['138', '1479245', '1479645', '-']
# Gene ID : CAGL0L13376r
# ['ChrL_C_glabrata_CBS138\tCGD\tgene\t1478858\t1479087\t.\t-\t.\tID=CAGL0L13376r']
# Coordinates : ['138', '1478858', '1479087', '-']
# Gene ID : CAGL0K12650g
# ['ChrK_C_glabrata_CBS138\tCGD\tgene\t1253813\t1256087\t.\t-\t.\tID=CAGL0K12650g']
# Coordinates : ['138', '1253813', '1256087', '-']
# Candida parapsilosis
# Gene ID : CPAR2_303740
# ['Contig005806_C_parapsilosis_CDC317\tCGD\tgene\t868743\t870311\t.\t-\t.\tID=CPAR2_303740']
# Coordinates : ['005806', '317', '868743', '870311']
# Gene ID : CPAR2_105550
# ['Contig005569_C_parapsilosis_CDC317\tCGD\tgene\t1206752\t1207969\t.\t-\t.\tID=CPAR2_105550']
# Coordinates : ['005569', '317', '1206752', '1207969']
# Gene ID : CPAR2_106400
# ['Contig005569_C_parapsilosis_CDC317\tCGD\tgene\t1372461\t1378190\t.\t-\t.\tID=CPAR2_106400']
# Coordinates : ['005569', '317', '1372461', '1378190']
# Gene ID : CPAR2_804030
# ['Contig005807_C_parapsilosis_CDC317\tCGD\tgene\t898440\t903626\t.\t-\t.\tID=CPAR2_804030']
# Coordinates : ['005807', '317', '898440', '903626']
# Gene ID : CPAR2_502030
# ['Contig006139_C_parapsilosis_CDC317\tCGD\tgene\t459483\t460139\t.\t-\t.\tID=CPAR2_502030']
# Coordinates : ['006139', '317', '459483', '460139']
# Gene ID : CPAR2_602820
# ['Contig005504_C_parapsilosis_CDC317\tCGD\tgene\t674661\t675143\t.\t+\t.\tID=CPAR2_602820']
# Coordinates : ['005504', '317', '674661', '675143']
# Gene ID : CPAR2_405290
# ['Contig006372_C_parapsilosis_CDC317\tCGD\tgene\t1191166\t1195680\t.\t-\t.\tID=CPAR2_405290']
# Coordinates : ['006372', '317', '1191166', '1195680']
# Gene ID : CPAR2_807270
# ['Contig005807_C_parapsilosis_CDC317\tCGD\tgene\t1677058\t1680444\t.\t+\t.\tID=CPAR2_807270']
# Coordinates : ['005807', '317', '1677058', '1680444']
# Gene ID : CPAR2_303510
# ['Contig005806_C_parapsilosis_CDC317\tCGD\tgene\t814158\t817100\t.\t+\t.\tID=CPAR2_303510']
# Coordinates : ['005806', '317', '814158', '817100']
# Gene ID : CPAR2_207280
# ['Contig005809_C_parapsilosis_CDC317\tCGD\tgene\t1546686\t1549229\t.\t+\t.\tID=CPAR2_207280']
# Coordinates : ['005809', '317', '1546686', '1549229']
# Gene ID : CPAR2_110330
# ['Contig005569_C_parapsilosis_CDC317\tCGD\tgene\t2196237\t2199341\t.\t+\t.\tID=CPAR2_110330']
# Coordinates : ['005569', '317', '2196237', '2199341']
# Gene ID : CPAR2_808620
# ['Contig005807_C_parapsilosis_CDC317\tCGD\tgene\t1989787\t1991289\t.\t-\t.\tID=CPAR2_808620']
# Coordinates : ['005807', '317', '1989787', '1991289']
# Gene ID : CPAR2_701565
# ['Contig006110_C_parapsilosis_CDC317\tCGD\tgene\t326587\t326737\t.\t+\t.\tID=CPAR2_701565']
# Coordinates : ['006110', '317', '326587', '326737']
# Gene ID : CPAR2_701550
# ['Contig006110_C_parapsilosis_CDC317\tCGD\tgene\t326308\t326430\t.\t+\t.\tID=CPAR2_701550']
# Coordinates : ['006110', '317', '326308', '326430']
# Gene ID : CPAR2_105880
# ['Contig005569_C_parapsilosis_CDC317\tCGD\tgene\t1278249\t1280002\t.\t-\t.\tID=CPAR2_105880']
# Coordinates : ['005569', '317', '1278249', '1280002']
# Candida tropicalis
# Gene ID : CTRG_05283
# ['GG692402\tVEuPathDB\tgene\t138041\t139627\t.\t-\t.\tID=gene:CTRG_05283']
# Coordinates : ['692402', '138041', '139627', '-']
# Gene ID : CTRG_04480
# ['GG692400\tVEuPathDB\tgene\t464325\t465503\t.\t-\t.\tID=gene:CTRG_04480']
# Coordinates : ['692400', '464325', '465503', '-']
# Gene ID : CTRG_04661
# ['GG692400\tVEuPathDB\tgene\t855888\t859730\t.\t+\t.\tID=gene:CTRG_04661']
# Coordinates : ['692400', '855888', '859730', '+']
# Gene ID : CTRG_02689
# ['GG692397\tVEuPathDB\tgene\t1450720\t1451376\t.\t+\t.\tID=gene:CTRG_02689']
# Coordinates : ['692397', '1450720', '1451376', '+']
# Gene ID : CTRG_02606
# ['GG692397\tVEuPathDB\tgene\t1242326\t1246822\t.\t-\t.\tID=gene:CTRG_02606']
# Coordinates : ['692397', '1242326', '1246822', '-']
# Gene ID : CTRG_02269
# ['GG692397\tVEuPathDB\tgene\t387555\t391007\t.\t-\t.\tID=gene:CTRG_02269']
# Coordinates : ['692397', '387555', '391007', '-']
# Gene ID : CTRG_05307
# ['GG692402\tVEuPathDB\tgene\t204686\t207517\t.\t-\t.\tID=gene:CTRG_05307']
# Coordinates : ['692402', '204686', '207517', '-']
# Gene ID : CTRG_03159
# ['GG692398\tVEuPathDB\tgene\t306193\t308541\t.\t-\t.\tID=gene:CTRG_03159']
# Coordinates : ['692398', '306193', '308541', '-']
# Gene ID : CTRG_04347
# ['GG692400\tVEuPathDB\tgene\t129027\t132158\t.\t+\t.\tID=gene:CTRG_04347']
# Coordinates : ['692400', '129027', '132158', '+']
# Gene ID : CTRG_05664
# ['GG692403\tVEuPathDB\tgene\t216861\t218552\t.\t+\t.\tID=gene:CTRG_05664']
# Coordinates : ['692403', '216861', '218552', '+']
# Gene ID : CTRG_02412
# ['GG692397\tVEuPathDB\tgene\t753775\t755433\t.\t-\t.\tID=gene:CTRG_02412']
# Coordinates : ['692397', '753775', '755433', '-']
# Cryptococcus neoformans
# Gene ID : CNA00300
# ['1\tena\tgene\t99512\t101925\t.\t+\t.\tID=gene:CNA00300']
# Coordinates : ['1', '99512', '101925', '+']
# Gene ID : CNN02320
# ['14\tena\tgene\t714977\t721785\t.\t+\t.\tID=gene:CNN02320']
# Coordinates : ['14', '714977', '721785', '+']
# Gene ID : CNE02100
# ['5\tena\tgene\t569042\t570826\t.\t-\t.\tID=gene:CNE02100']
# Coordinates : ['5', '569042', '570826', '-']
# Gene ID : CNA05950
# ['1\tena\tgene\t1593426\t1594383\t.\t-\t.\tID=gene:CNA05950']
# Coordinates : ['1', '1593426', '1594383', '-']
# Gene ID : CNF04830
# ['6\tena\tgene\t1402888\t1407678\t.\t-\t.\tID=gene:CNF04830']
# Coordinates : ['6', '1402888', '1407678', '-']
# Gene ID : CNB04020
# ['2\tena\tgene\t1180968\t1183198\t.\t+\t.\tID=gene:CNB04020']
# Coordinates : ['2', '1180968', '1183198', '+']
# Gene ID : CNC01920
# ['3\tena\tgene\t521279\t523892\t.\t+\t.\tID=gene:CNC01920']
# Coordinates : ['3', '521279', '523892', '+']
# Gene ID : CNA07090
# ['1\tena\tgene\t1924447\t1930885\t.\t+\t.\tID=gene:CNA07090']
# Coordinates : ['1', '1924447', '1930885', '+']
# Pichia kudriavzevii
# Gene ID : JL09_g2508
# ['scaffold00021\tena\tgene\t51640\t53226\t.\t+\t.\tID=gene:JL09_g2508']
# Coordinates : ['00021', '51640', '53226', '+']
# Gene ID : JL09_g3074
# ['scaffold00030\tena\tgene\t2265\t3332\t.\t-\t.\tID=gene:JL09_g3074']
# Coordinates : ['00030', '2265', '3332', '-']
# Gene ID : JL09_g1956
# ['scaffold00014\tena\tgene\t156416\t161437\t.\t-\t.\tID=gene:JL09_g1956']
# Coordinates : ['00014', '156416', '161437', '-']
# Gene ID : JL09_g2004
# ['scaffold00015\tena\tgene\t65198\t68933\t.\t+\t.\tID=gene:JL09_g2004']
# Coordinates : ['00015', '65198', '68933', '+']
# Gene ID : JL09_g66
# ['contig04490\tena\tgene\t9\t342\t.\t-\t.\tID=gene:JL09_g66', 'contig04491\tena\tgene\t9\t384\t.\t-\t.\tID=gene:JL09_g66', 'contig04492\tena\tgene\t37\t320\t.\t+\t.\tID=gene:JL09_g66', 'contig04493\tena\tgene\t77\t360\t.\t-\t.\tID=gene:JL09_g66', 'contig04494\tena\tgene\t94\t193\t.\t-\t.\tID=gene:JL09_g66', 'contig04495\tena\tgene\t14\t172\t.\t+\t.\tID=gene:JL09_g66', 'contig04496\tena\tgene\t17\t219\t.\t+\t.\tID=gene:JL09_g66', 'contig04497\tena\tgene\t175\t297\t.\t+\t.\tID=gene:JL09_g66', 'contig04498\tena\tgene\t14\t172\t.\t+\t.\tID=gene:JL09_g66', 'contig04499\tena\tgene\t197\t297\t.\t+\t.\tID=gene:JL09_g66', 'contig04500\tena\tgene\t40\t387\t.\t-\t.\tID=gene:JL09_g66', 'contig04501\tena\tgene\t179\t381\t.\t-\t.\tID=gene:JL09_g66', 'contig04503\tena\tgene\t95\t168\t.\t+\t.\tID=gene:JL09_g66', 'contig04504\tena\tgene\t44\t111\t.\t+\t.\tID=gene:JL09_g66', 'contig04505\tena\tgene\t149\t267\t.\t-\t.\tID=gene:JL09_g66', 'contig04506\tena\tgene\t192\t362\t.\t+\t.\tID=gene:JL09_g66', 'contig04507\tena\tgene\t94\t193\t.\t-\t.\tID=gene:JL09_g66', 'contig04508\tena\tgene\t48\t383\t.\t+\t.\tID=gene:JL09_g66', 'contig04509\tena\tgene\t48\t383\t.\t+\t.\tID=gene:JL09_g66', 'contig04510\tena\tgene\t39\t380\t.\t-\t.\tID=gene:JL09_g66', 'contig04511\tena\tgene\t93\t276\t.\t-\t.\tID=gene:JL09_g66', 'contig04513\tena\tgene\t65\t373\t.\t+\t.\tID=gene:JL09_g66', 'contig04514\tena\tgene\t18\t367\t.\t+\t.\tID=gene:JL09_g66', 'contig04515\tena\tgene\t18\t367\t.\t+\t.\tID=gene:JL09_g66', 'contig04516\tena\tgene\t65\t373\t.\t+\t.\tID=gene:JL09_g66', 'contig04517\tena\tgene\t47\t226\t.\t-\t.\tID=gene:JL09_g66', 'contig04518\tena\tgene\t24\t134\t.\t-\t.\tID=gene:JL09_g66', 'contig04519\tena\tgene\t17\t355\t.\t-\t.\tID=gene:JL09_g66', 'contig04520\tena\tgene\t80\t347\t.\t+\t.\tID=gene:JL09_g66', 'contig04521\tena\tgene\t17\t355\t.\t-\t.\tID=gene:JL09_g66', 'contig04522\tena\tgene\t80\t349\t.\t+\t.\tID=gene:JL09_g66', 'contig04523\tena\tgene\t204\t349\t.\t+\t.\tID=gene:JL09_g66', 'contig04524\tena\tgene\t32\t368\t.\t+\t.\tID=gene:JL09_g66', 'contig04525\tena\tgene\t18\t354\t.\t-\t.\tID=gene:JL09_g66', 'contig04526\tena\tgene\t24\t365\t.\t+\t.\tID=gene:JL09_g66', 'contig04527\tena\tgene\t197\t225\t.\t+\t.\tID=gene:JL09_g66', 'contig04528\tena\tgene\t24\t365\t.\t+\t.\tID=gene:JL09_g66', 'contig04529\tena\tgene\t92\t173\t.\t-\t.\tID=gene:JL09_g66', 'contig04530\tena\tgene\t11\t267\t.\t-\t.\tID=gene:JL09_g66', 'contig04531\tena\tgene\t11\t267\t.\t-\t.\tID=gene:JL09_g66', 'contig04532\tena\tgene\t154\t371\t.\t+\t.\tID=gene:JL09_g66', 'contig04533\tena\tgene\t83\t163\t.\t+\t.\tID=gene:JL09_g66', 'contig04534\tena\tgene\t116\t141\t.\t+\t.\tID=gene:JL09_g66', 'contig04535\tena\tgene\t196\t353\t.\t+\t.\tID=gene:JL09_g66', 'contig04536\tena\tgene\t195\t307\t.\t+\t.\tID=gene:JL09_g66', 'contig04537\tena\tgene\t36\t323\t.\t-\t.\tID=gene:JL09_g66', 'contig04538\tena\tgene\t20\t331\t.\t-\t.\tID=gene:JL09_g66', 'contig04539\tena\tgene\t20\t331\t.\t-\t.\tID=gene:JL09_g66', 'contig04540\tena\tgene\t26\t363\t.\t+\t.\tID=gene:JL09_g66', 'contig04541\tena\tgene\t58\t345\t.\t+\t.\tID=gene:JL09_g66', 'contig04542\tena\tgene\t26\t363\t.\t+\t.\tID=gene:JL09_g66', 'contig04543\tena\tgene\t99\t238\t.\t-\t.\tID=gene:JL09_g66', 'contig04544\tena\tgene\t99\t238\t.\t-\t.\tID=gene:JL09_g66', 'contig04545\tena\tgene\t183\t307\t.\t+\t.\tID=gene:JL09_g66', 'contig04546\tena\tgene\t66\t365\t.\t+\t.\tID=gene:JL09_g66', 'contig04547\tena\tgene\t42\t267\t.\t-\t.\tID=gene:JL09_g66', 'contig04548\tena\tgene\t112\t280\t.\t+\t.\tID=gene:JL09_g66', 'contig04549\tena\tgene\t280\t326\t.\t-\t.\tID=gene:JL09_g66', 'contig04550\tena\tgene\t183\t307\t.\t+\t.\tID=gene:JL09_g66', 'contig04551\tena\tgene\t76\t129\t.\t+\t.\tID=gene:JL09_g66', 'contig04552\tena\tgene\t26\t96\t.\t+\t.\tID=gene:JL09_g66', 'contig04554\tena\tgene\t280\t326\t.\t-\t.\tID=gene:JL09_g66', 'contig04555\tena\tgene\t14\t337\t.\t-\t.\tID=gene:JL09_g66', 'contig04557\tena\tgene\t9\t357\t.\t-\t.\tID=gene:JL09_g66', 'contig04558\tena\t ...
# Coordinates : ['04490', '9', '342', '-']
# Gene ID : JL09_g570
# ['contig03556\tena\tgene\t23\t215\t.\t-\t.\tID=gene:JL09_g570', 'contig03557\tena\tgene\t88\t917\t.\t-\t.\tID=gene:JL09_g570', 'contig03558\tena\tgene\t135\t951\t.\t+\t.\tID=gene:JL09_g570', 'contig03559\tena\tgene\t38\t494\t.\t-\t.\tID=gene:JL09_g570', 'contig03560\tena\tgene\t624\t945\t.\t+\t.\tID=gene:JL09_g570', 'contig03561\tena\tgene\t269\t370\t.\t+\t.\tID=gene:JL09_g570', 'contig03562\tena\tgene\t673\t875\t.\t-\t.\tID=gene:JL09_g570', 'contig03563\tena\tgene\t35\t940\t.\t-\t.\tID=gene:JL09_g570', 'contig03564\tena\tgene\t69\t699\t.\t-\t.\tID=gene:JL09_g570', 'contig03565\tena\tgene\t64\t939\t.\t+\t.\tID=gene:JL09_g570', 'scaffold00003\tena\tgene\t83505\t86693\t.\t-\t.\tID=gene:JL09_g570']
# Coordinates : ['03556', '23', '215', '-']

# %% [markdown]
# # Fasta file creation

# %%
synth_w_newlines = re.sub("(.{60})", "\\1\n", synth, 0, re.DOTALL)

fasta_header = ">synthetic genome, author GiguereM\n"

my_synth_genome = open("my_synthetic_genome.txt", "w")
my_synth_genome.write(fasta_header + synth_w_newlines)
my_synth_genome.close()

# %% [markdown]
# # Update !!
#
# ### In GFF, the start and end coordinates of the feature are given in positive 1-based integer coordinates, relative to the **landmark given in column one**.
#
# ### So I will implement a regex to get the landmark of a gene, and add it to its sequence coordinates !!!
